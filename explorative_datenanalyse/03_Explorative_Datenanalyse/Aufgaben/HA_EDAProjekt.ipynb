# %% [markdown]
# ![image info](https://user-images.githubusercontent.com/91945811/146929832-e78ff1f4-2739-41b1-acd3-019a39b6a42c.png)

# %% [markdown]
# ### **Erforderliche Bibliotheken:**
# 1. **`pandas`** – zum Laden, Verarbeiten und Filtern der Wetterdaten (`pd.read_excel()`, `pd.to_datetime()`, `df.describe()`, `df.set_index()`, `pd.cut()`, etc.).
# 2. **`matplotlib.pyplot`** – für die Visualisierung (`plt.figure()`, `plt.plot()`, `plt.show()`, `plt.title()`, `plt.xlabel()`, `plt.ylabel()`, etc.).
# 3. **`seaborn`** – für erweiterte Datenvisualisierung (`sns.lineplot()`, `sns.histplot()`, `sns.boxplot()`, `sns.heatmap()`).

# %% [markdown]
# ## **Aufgabe: Explorative Datenanalyse (EDA)**
#
# ### **Überblick über die Datenstruktur**
# Führe eine erste Analyse des Datensatzes durch, um die grundlegende Struktur zu verstehen.
#
# #### **Aufgaben:**
# 1. Lade den Datensatz `huhn.xlsx` in einen DataFrame.
# 2. Zeige die ersten Zeilen der Daten an, um einen Überblick über den Inhalt zu erhalten.
# 3. Überprüfe die Datentypen der Spalten und stelle fest, ob es fehlende Werte gibt.
#
# <details>
#   <summary>Hinweise anzeigen</summary>
#
# #### **Hinweise:**
# - Verwende `pd.read_excel()`, um die Datei einzulesen.
# - Nutze `df.head()` oder `display(df)`, um die ersten Zeilen anzuzeigen.
# - `df.info()` gibt dir eine Zusammenfassung der Datenstruktur, inklusive Datentypen und fehlender Werte.
#
# </details>
#
# ---

# %% [markdown]
# ## **Aufgabe: Deskriptive Statistik**
#
# ### **Grundlegende Statistiken für numerische Variablen**
# Analysiere die numerischen Spalten des Datensatzes und gewinne erste Einblicke in die Werteverteilung.
#
# #### **Aufgaben:**
# 1. Berechne die grundlegenden statistischen Kennzahlen für alle numerischen Spalten:
#    - Minimum (Min)
#    - Maximum (Max)
#    - Mittelwert (Mean)
#    - Median
#    - Standardabweichung (Std)
# 2. Interpretiere die Ergebnisse:
#    - Gibt es große Unterschiede zwischen Mittelwert und Median?
#    - Gibt es auffällige Werte, die möglicherweise Ausreißer sind?
#
# <details>
#   <summary>Hinweise anzeigen</summary>
#
# #### **Hinweise:**
# - Verwende `df.describe()`, um eine schnelle Übersicht der wichtigsten statistischen Kennzahlen zu erhalten.
# - Beachte, dass `describe()` standardmäßig nur numerische Spalten berücksichtigt.
# - Falls du den Median explizit berechnen möchtest, nutze `df.median()`.
# - Falls du extreme Werte oder mögliche Ausreißer identifizieren möchtest, achte auf große Standardabweichungen oder ungewöhnlich hohe/kleine Min- und Max-Werte.
#
#     </details>

# %% [markdown]
# ## **Aufgabe: Visualisierungen**
#
#
# *Disclaimer*: Mit rund 50 Hühnern und teils ungleich verteilten Futtergruppen lassen die Ergebnisse noch keine endgültigen Schlüsse zu – sie zeigen aber bereits interessante Tendenzen, die man mit weiteren Studien untersuchen könnte.
#
#
# ### **1. Gewicht und Alter pro Futterart**
# Erstelle eine Visualisierung, die zeigt, wie sich das Gewicht der Hühner in Abhängigkeit von ihrem Alter und der Futterart entwickelt.
#
# #### **Aufgaben:**
# 1. Gruppiere den Datensatz nach Alter und Futterart.
# 2. Berechne das durchschnittliche Gewicht für jede Kombination aus Alter und Futterart.
# 3. Erstelle ein gruppiertes Liniendiagramm, um die Gewichtsentwicklung der Hühner über die Zeit für verschiedene Futterarten darzustellen.
# 4. Beschrifte die Achsen und den Titel der Grafik sinnvoll.
#
# <details>
#   <summary>Hinweise anzeigen</summary>
#
# #### **Hinweise:**
# - Verwende `groupby(['alter', 'futter'])['gewicht'].mean().unstack()` zur Gruppierung und Berechnung der Mittelwerte.
# - Erstelle das Liniendiagramm, bspw. mit `df.plot(kind='line')` oder mit `sns.lineplot()`.
# - Achte darauf, die Achsen zu beschriften, einen Titel zu setzen und eine Legende zu integrieren.
# - Optional kannst du das Balkendiagramm um ein Gitter (`plt.grid()`) ergänzen, um die Lesbarkeit zu verbessern.
#
#     </details>

# %% [markdown]
# ### **2. Gewichtsentwicklung der Hühner über die Zeit**
# Erstelle eine Visualisierung, die den Gewichtsverlauf einzelner Hühner über die Zeit zeigt.
#
# #### **Aufgaben:**
# 1. Erstelle ein **Liniendiagramm**, das den Gewichtsverlauf der einzelnen Hühner (`huhn`) über die Zeit (`alter`) darstellt.
# 2. Nutze verschiedene Farben für unterschiedliche Hühner, um deren individuelle Entwicklungen sichtbar zu machen.
# 3. Ergänze Markierungen an den Datenpunkten, um die Werte hervorzuheben.
# 4. Setze sinnvolle Achsenbeschriftungen und einen Titel.
# 5. Füge ein Raster hinzu, um die Lesbarkeit der Werte zu verbessern.
#
# <details>
#   <summary>Hinweise anzeigen</summary>
#
#
# #### **Hinweise:**
# - Nutze `sns.lineplot()` für die Darstellung, wobei `hue="huhn"` die Linien pro Huhn farblich unterscheidet.
# - Der Parameter `marker="o"` sorgt für Markierungen an den Datenpunkten.
# - Falls die Legende zu überladen ist, kannst du sie mit `legend=False` ausblenden.
# - Nutze `plt.grid(axis='y', linestyle='--', alpha=0.7)`, um das Raster nur für die y-Achse anzuzeigen.
#
#   </details>

# %% [markdown]
# ### **3. Vergleich der Gewichtsentwicklung nach Futterart (Facettierte Liniendiagramme)**
# Erstelle eine Visualisierung, die den Einfluss der Futterart auf die Gewichtsentwicklung der Hühner über die Zeit darstellt.
#
# #### **Aufgaben:**
# 1. Erstelle **separate Liniendiagramme für jede Futterart**, um den Gewichtsverlauf der Hühner über die Zeit (`alter`) zu vergleichen.
# 2. Stelle sicher, dass jedes Diagramm nur die Hühner zeigt, die mit einer bestimmten Futterart gefüttert wurden.
# 3. Nutze verschiedene Farben für die Hühner, um individuelle Gewichtsentwicklungen sichtbar zu machen.
# 4. Setze sinnvolle Achsenbeschriftungen und einen Titel.
# 5. Verwende eine einheitliche Skalierung für alle Diagramme, damit die Unterschiede zwischen den Futterarten gut vergleichbar sind.
#
# <details>
#   <summary>Hinweise anzeigen</summary>
#
# #### **Hinweise:**
# - Verwende `sns.relplot()` mit `col="futter"`, um für jede Futterart ein eigenes Diagramm zu erzeugen.
# - Der Parameter `col_wrap=2` sorgt dafür, dass maximal zwei Diagramme nebeneinander stehen (gut für eine bessere Übersicht).
# - `facet_kws={'sharex': True, 'sharey': True}` stellt sicher, dass alle Diagramme dieselben Achsenskalierungen haben.
# - Der Parameter `marker="o"` hebt die Datenpunkte hervor.
# - Falls du viele Hühner hast und die Diagramme unübersichtlich wirken, kannst du `legend=False` setzen oder die `alpha`-Transparenz anpassen.
#
#   </details>

# %% [markdown]
# ### **4. Untersuchung der Korrelationen zwischen Gewicht, Alter und Futterart**
# Analysiere, wie stark die einzelnen numerischen Merkmale des Datensatzes miteinander korrelieren.
#
# #### **Aufgaben:**
# 1. Berechne die **Korrelationsmatrix** für die numerischen Variablen im Datensatz.
# 2. Visualisiere die Korrelationen mithilfe einer **Heatmap**, um Zusammenhänge auf einen Blick erkennbar zu machen.
# 3. Interpretiere die Ergebnisse:
#    - Welche Variablen sind besonders stark miteinander korreliert?
#    - Gibt es schwache oder negative Korrelationen?
#
# <details>
#   <summary>Hinweise anzeigen</summary>
#
# #### **Hinweise:**
# - Nutze `df.corr()`, um die Korrelationsmatrix zu berechnen.
# - Verwende `sns.heatmap()`, um die Korrelationen in einer farblichen Matrix darzustellen.
# - Der Parameter `annot=True` sorgt dafür, dass die Korrelationswerte direkt in der Heatmap angezeigt werden.
# - `cmap="coolwarm"` bietet eine kontrastreiche Farbpalette zur besseren Visualisierung positiver und negativer Korrelationen.
#
#   </details>

# %% [markdown]
# ### **5. Einteilung in Altersklassen und Visualisierung der Gewichtsunterschiede**
# Untersuche, wie sich das Gewicht der Hühner in verschiedenen Altersstufen unterscheidet und ob die Futterart einen Einfluss hat.
#
# #### **Aufgaben:**
# 1. **Definiere drei Altersklassen** für die Hühner basierend auf ihrem Alter (`alter`):
#    - **Jung**: 0–7 Tage
#    - **Mittel**: 8–14 Tage
#    - **Alt**: Ab 15 Tagen
# 2. Weise jedem Huhn basierend auf seinem Alter eine Altersklasse zu.
# 3. Erstelle ein **Boxplot**, das die Verteilung des Gewichts in diesen Altersklassen zeigt.
# 4. Unterscheide in der Visualisierung zusätzlich nach Futterart, um mögliche Unterschiede sichtbar zu machen.
# 5. Setze sinnvolle Achsenbeschriftungen und einen Titel.
#
# <details>
#   <summary>Hinweise anzeigen</summary>
#
# #### **Hinweise:**
# - Verwende `pd.cut()`, um die Altersklassen zu definieren.
# - `sns.boxplot()` eignet sich gut, um die Verteilung der Gewichte je Altersklasse und Futterart zu visualisieren.
# - Nutze `hue="futter"`, um die unterschiedlichen Futterarten in verschiedenen Farben darzustellen.
# - Falls nötig, kannst du die `bins` der Altersklassen anpassen, um eine sinnvollere Gruppierung zu erhalten.
# - Ein **Boxplot** zeigt Median, Quartile, mögliche Ausreißer und hilft, Unterschiede in der Gewichtsverteilung klar zu erkennen.
#
#   </details>

# %% [markdown]
# # Aufgabe: Fazit
#
# Fasse zum Schluss einmal deine wichtigsten Erknntnisse zusammen.
# Welches Futter ist für eine hohe Gewichtsentwicklung am besten?
# In welchem Alter gibt es die meisten Unterschiede/ Gemeinsamkeiten?
# Überlege dir, was für Informationen du noch aus den Diagrammen ableiten kannst und schreibe eine kurze Empfehlung, was du aus diesen Daten schließt.
