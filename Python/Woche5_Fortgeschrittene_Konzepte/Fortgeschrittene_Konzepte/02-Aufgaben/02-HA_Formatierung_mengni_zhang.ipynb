# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Übungen - Formatierung mit f-Strings

# %% [markdown]
# # Inhaltsverzeichnis
#
# - **Aufgaben Formatierung**
#     - **Aufgabe 1: Produkt zweier Zahlen**
#     - **Aufgabe 2: Division zweiter Zahlen**
#     - **Aufgabe 3: Riesige Zahl in Tausenderformat**
#     - **Aufgabe 4: Konsolenausgabe von Personendaten**
#     - **Aufgabe 5: Zugriff auf Dictionary-Werte mit f-Strings**

# %% [markdown]
# ## Aufgabe 1: Produkt zweier Zahlen
#
# Schreibe ein Programm, das:
#
# - Zwei Zahlen `x` und `y` von einem Benutzer anfordert und speichert.
# - Direkt das Produkt dieser Zahlen ausgibt, ohne eine zusätzliche Variable zu definieren.
#
# ### Anforderungen:
# - Verwende `f`-Strings, um das Ergebnis zu formatieren und auszugeben.

# %%
x = float(input("Bitte die Nummer x eingeben: ").strip())
y = float(input("Bitte die Nummer y eingeben: ").strip())

print(f"Das Produkt von {x} und {y} ist {x * y}.")

# %% [markdown]
# ## Aufgabe 2: Division zweier Zahlen
#
# Schreibe ein Programm, das nach zwei Zahlen fragt und diese Werte in den Variablen `x` und `y` speichert. Das Programm soll dann ohne eine weitere Variable zu definieren, die Division der Zahlen mit nur einer Nachkommastelle auf der Konsole ausgeben.
#
# ### Anforderungen:
# - Die Eingabewerte `x` und `y` sollen vom Typ `float` sein.
# - Die Ausgabe soll die Division von `x` durch `y` sein, formatiert mit genau einer Nachkommastelle.

# %%
x = float(input("Bitte die Nummer x eingeben: ").strip())
y = float(input("Bitte die Nummer y eingeben: ").strip())

print(f"Die Division von {x} durch {y} ist {x / y:.1f}.")

# %% [markdown]
# ## Aufgabe 3: Riesige Zahl in Tausenderformat
#
# Schreibe eine Funktion `format_number`, die eine sehr große Zahl als Argument entgegennimmt und diese Zahl in einem Tausenderformat als String zurückgibt, ohne die Zahl in einer Variablen zu speichern. Verwende dabei Unterstriche (`_`) als Tausendertrennzeichen.
#
# ### Anforderungen:
# - Die Funktion `format_number(number: int) -> str` nimmt eine große ganze Zahl entgegen und gibt diese im Tausenderformat als String zurück.

# %%
def format_number(number: int) -> str:
    return f"{number:_}"

# %%
assert format_number(1999999) == "1_999_999"

# %% [markdown]
# ## Aufgabe 4: Konsolenausgabe von Personendaten
#
# Gegeben sind drei Listen mit Informationen zu 20 unterschiedlichen Personen: `name`, `email` und `work`.
# Verwende eine `for`-Schleife und die `zip`-Funktion, um durch die Listen gleichzeitig zu iterieren und gib für jede Person alle Informationen in einem formatierten Satz auf der Konsole aus, entsprechend dem vorgegebenen Ausgabeformat.
#
# ### Anforderungen:
# - Implementiere eine Schleife, die die drei Listen `name`, `email` und `work` durchläuft.
# - Verwende die `zip`-Funktion, um die Elemente der drei Listen zusammenzuführen.
# - Die Ausgabe soll für jede Person einen formatierten Satz beinhalten, der den Namen, die E-Mail und den Beruf enthält.
# - Die Ausgabe soll linksbündig für den Namen, zentriert für die E-Mail und rechtsbündig für den Beruf sein, ähnlich wie im gegebenen Bild.
#
# > ![image.png](attachment:image.png)

# %%
name = [
    "Evelyn Richardson",
    "Lilianna Bailey",
    "Alexander Chapman",
    "Dainton Riley",
    "Alfred Wilson",
    "Adison Davis",
    "Audrey Thompson",
    "Maximilian Cameron",
    "Spike Payne",
    "Jenna Scott",
    "Julian Mitchell",
    "Miller Robinson",
    "Alford Reed",
    "Haris Campbell",
    "Michael Carter",
    "Lydia Barnes",
    "Arthur Harrison",
    "David Harrison",
    "Chester Gray",
    "Paul Hill",
]
email = [
    "e.richardson@randatmail.com",
    "l.bailey@randatmail.com",
    "a.chapman@randatmail.com",
    "d.riley@randatmail.com",
    "a.wilson@randatmail.com",
    "a.davis@randatmail.com",
    "a.thompson@randatmail.com",
    "m.cameron@randatmail.com",
    "s.payne@randatmail.com",
    "j.scott@randatmail.com",
    "j.mitchell@randatmail.com",
    "m.robinson@randatmail.com",
    "a.reed@randatmail.com",
    "h.campbell@randatmail.com",
    "m.carter@randatmail.com",
    "l.barnes@randatmail.com",
    "a.harrison@randatmail.com",
    "d.harrison@randatmail.com",
    "c.gray@randatmail.com",
    "p.hill@randatmail.com",
]
work = [
    "Physicist",
    "Cook",
    "Teacher",
    "Geologist",
    "Driver",
    "Firefighter",
    "Economist",
    "Programmer",
    "Composer",
    "Salesman",
    "Archeologist",
    "Aeroplane Pilot",
    "Actor",
    "Social Worker",
    "Carpenter",
    "Geologist",
    "Composer",
    "Interpreter",
    "Graphic Designer",
    "Jeweller",
]

# %%
for person_name, person_email, person_work in zip(name, email, work):
    print(f"{person_name:<20} under {person_email:^30} work as {person_work:>20}")

# %% [markdown]
# ## Aufgabe 5: Zugriff auf Dictionary-Werte mit f-Strings
#
# Gegeben ist ein Dictionary, das drei Automarken als Schlüssel enthält, wobei jeder Schlüssel den Suffix `'_car'` hat, und deren jeweilige Anzahl als Wert.<br><br>
# Implementiere eine Schleife, die die Anzahl jedes Autos ausgibt, indem auf die Werte im Dictionary mittels verschachtelter f-Strings zugegriffen wird.
#
# ### Anforderungen:
# - Verwende ein Dictionary mit Automarken als Schlüssel und einem Suffix `'_car'` für jeden Schlüssel.
# - Zugriff auf die Werte soll innerhalb eines f-Strings erfolgen.
# - Die Schleife soll für jede Marke die Anzahl der Autos auf der Konsole ausgeben.

# %%
cars = {"audi_car": 3, "bmw_car": 5, "mercedes_car": 2}

# %%
for key, value in cars.items():
    print(f"Es gibt {value} {key[:-4].capitalize()} Autos.")
