# %%
import random
import statistics

# %%
def roll_dice(n: int = 1) -> list[int]:
    roll_result = []
    for i in range(1, n + 1):
        roll_result.append(random.randint(1, 6))
    return roll_result

# %%
def average_roll_numbers(n: int = 1) -> float:
    average = statistics.mean(roll_dice(n))
    return average

# %%
for i in [2, 4, 6, 8, 10, 100, 1000, 10000, 100000, 100000, 1000000]:
    print(f"Wenn n={i} ist, beträgt der berechnete Mittelwert {average_roll_numbers(i)}.")
# Out:
# Wenn n=2 ist, beträgt der berechnete Mittelwert 4.5.
# Wenn n=4 ist, beträgt der berechnete Mittelwert 4.75.
# Wenn n=6 ist, beträgt der berechnete Mittelwert 4.166666666666667.
# Wenn n=8 ist, beträgt der berechnete Mittelwert 3.
# Wenn n=10 ist, beträgt der berechnete Mittelwert 3.7.
# Wenn n=100 ist, beträgt der berechnete Mittelwert 3.6.
# Wenn n=1000 ist, beträgt der berechnete Mittelwert 3.568.
# Wenn n=10000 ist, beträgt der berechnete Mittelwert 3.4926.
# Wenn n=100000 ist, beträgt der berechnete Mittelwert 3.502.
# Wenn n=100000 ist, beträgt der berechnete Mittelwert 3.51265.
# Wenn n=1000000 ist, beträgt der berechnete Mittelwert 3.501958.
